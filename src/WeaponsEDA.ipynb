# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
import scipy

# %%
# read csv
filePath = '../data/SkyrimWeapons.csv'
SkyrimWeaponsData = pd.read_csv(filePath)
print(SkyrimWeaponsData.shape)
# Out:
# (293, 9)

# %% [markdown]
# We have 239 rows and 9 cols

# %%
print(SkyrimWeaponsData.Type.unique())
print(SkyrimWeaponsData.Type.unique().shape)
# Out:
# ['Battleaxe' 'Dagger' 'Mace' 'Sword' 'War Axe' 'Silverware' 'Greatsword'
#  'Warhammer' 'Bow' 'Arrow' 'Crossbow' 'Bolt']
# (12,)

# %% [markdown]
# We have 12 types of weapons in the original data, we can discard silverware, arrows and bolts for now

# %%
SkyrimWeaponsData = SkyrimWeaponsData.loc[(SkyrimWeaponsData['Type'] != 'Arrow') & (SkyrimWeaponsData['Type'] != 'Bolt') & (SkyrimWeaponsData['Type'] != 'Silverware')]
SkyrimWeaponsData
# Out:
#                           Name  Damage  Weight  Gold              Upgrade
# 0      Ancient Nord Battle Axe      18    22.0    28          Steel Ingot  \
# 1            Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2        Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 3         Drainblood Battleaxe      21     5.0   266                  NaN
# 4            Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
# ..                         ...     ...     ...   ...                  ...
# 260                  Zephyr DG      12    10.0   670  Dwarven Metal Ingot
# 281                   Crossbow      19    14.0   120          Steel Ingot
# 282           Dwarven Crossbow      22    20.0   350  Dwarven metal ingot
# 283          Enhanced Crossbow      19    15.0   200          Steel Ingot
# 284  Enhanced Dwarven Crossbow      22    21.0   550  Dwarven metal ingot
#
#         Perk       Type    Category  Speed
# 0      Steel  Battleaxe  Two-Handed    NaN
# 1    Daedric  Battleaxe  Two-Handed    NaN
# 2     Dragon  Battleaxe  Two-Handed    NaN
# 3          -  Battleaxe  Two-Handed    NaN
# 4    Dwarven  Battleaxe  Two-Handed    NaN
# ..       ...        ...         ...    ...
# 260  Dwarven        Bow     Archery    1.0
# 281      NaN   Crossbow     Archery    NaN
# 282      NaN   Crossbow     Archery    NaN
# 283      NaN   Crossbow     Archery    NaN
# 284      NaN   Crossbow     Archery    NaN
#
# [263 rows x 9 columns]

# %% [markdown]
# We now have 263 rows and 9 columns

# %%
print(SkyrimWeaponsData.Damage.describe())
# Out:
# count    263.000000
# mean      13.095057
# std        5.633401
# min        1.000000
# 25%        9.000000
# 50%       12.000000
# 75%       17.000000
# max       28.000000
# Name: Damage, dtype: float64

# %%
weakestWeapon = SkyrimWeaponsData.sort_values(by='Damage')
weakestWeapon = weakestWeapon.iloc[:10]
weakestWeapon
# Out:
#                  Name  Damage  Weight  Gold      Upgrade   Perk     Type
# 161  Illusory War Axe       1    14.0    15          NaN      –  War Axe  \
# 126     Phantom Sword       1     0.0     0          NaN      -    Sword
# 143     Wooden Sword        2     3.0    25     Firewood    NaN    Sword
# 34        Iron Dagger       4     2.0    10   Iron Ingot    NaN   Dagger
# 45       Steel Dagger       5     2.5    18  Steel Ingot  Steel   Dagger
# 175     Poacher's Axe       5    10.0    32  Steel Ingot    NaN  War Axe
# 42               Shiv       5     2.0     5          NaN      -   Dagger
# 41     Rundi's Dagger       5     2.5    18  Steel Ingot  Steel   Dagger
# 171   Notched Pickaxe       5    10.0   303   Iron Ingot    NaN  War Axe
# 180  Woodcutter's Axe       5    10.0     5          NaN      –  War Axe
#
#        Category  Speed
# 161  One-Handed    NaN
# 126  One-Handed    NaN
# 143  One-Handed    NaN
# 34   One-Handed    NaN
# 45   One-Handed    NaN
# 175  One-Handed    NaN
# 42   One-Handed    NaN
# 41   One-Handed    NaN
# 171  One-Handed    NaN
# 180  One-Handed    NaN

# %%
strongestWeapon = SkyrimWeaponsData.sort_values(by='Damage', ascending=False)
strongestWeapon = strongestWeapon.iloc[:10]
strongestWeapon
# Out:
#                       Name  Damage  Weight  Gold      Upgrade     Perk
# 208  Dragonbone Warhammer       28    33.0  4275  Dragon Bone   Dragon  \
# 205      Daedric Warhammer      27    31.0  4000  Ebony Ingot  Daedric
# 20        Tsun's Battleaxe      27    36.0  1000          NaN        -
# 217    Stalhrim Warhammer       26    29.0  2850     Stalhrim    Ebony
# 2    Dragonbone Battleaxe       26    30.0  3000  Dragon Bone   Dragon
# 21                Wuuthrad      25    25.0  2000          NaN        -
# 248          Karliah's Bow      25     9.0     5          NaN        -
# 210        Ebony Warhammer      25    30.0  1725  Ebony Ingot    Ebony
# 221             Volendrung      25    26.0  1843  Ebony Ingot      NaN
# 1        Daedric Battleaxe      25    27.0  2750  Ebony Ingot  Daedric
#
#           Type    Category  Speed
# 208  Warhammer  Two-Handed    NaN
# 205  Warhammer  Two-Handed    NaN
# 20   Battleaxe  Two-Handed    NaN
# 217  Warhammer  Two-Handed    NaN
# 2    Battleaxe  Two-Handed    NaN
# 21   Battleaxe  Two-Handed    NaN
# 248        Bow     Archery  0.625
# 210  Warhammer  Two-Handed    NaN
# 221  Warhammer  Two-Handed    NaN
# 1    Battleaxe  Two-Handed    NaN

# %% [markdown]
# From the previous data we can see that most of the weak weapons are one handed and most of the stronger weapons are 2 handed
#
# We also notice that swords and daggers are common in the weak weapons caregory and warhammers and battleaxes are more common in the strong weapons category

# %%
plt.pyplot.Figure(figsize=(10,40))
sns.barplot(x=SkyrimWeaponsData['Category'], y=SkyrimWeaponsData['Damage'])
# Out:
# <Axes: xlabel='Category', ylabel='Damage'>

# %% [markdown]
# We can see that 2 handed weapons are superior in terms of damage and one handed weapons are not that great

# %%
plt.rcParams['figure.figsize'] = 12,8
sns.boxplot(x=SkyrimWeaponsData['Type'], y=SkyrimWeaponsData['Damage'], hue=SkyrimWeaponsData['Category'])
# Out:
# <Axes: xlabel='Type', ylabel='Damage'>

# %% [markdown]
# Boxplots allow us to see that 2 handed weapons have a high mean damage. Bows have much lower mean damage but theres an outlier which rivals the damage of some warhammers. One handed weapons have low mean damages with swords and war axes having outliers which bring their means down by a lot

# %% [markdown]
# Heaviest Weapons

# %%
SkyrimWeaponsData.sort_values('Weight', ascending=False)
# Out:
#                       Name  Damage  Weight  Gold      Upgrade     Perk
# 20        Tsun's Battleaxe      27    36.0  1000          NaN        -  \
# 208  Dragonbone Warhammer       28    33.0  4275  Dragon Bone   Dragon
# 205      Daedric Warhammer      27    31.0  4000  Ebony Ingot  Daedric
# 2    Dragonbone Battleaxe       26    30.0  3000  Dragon Bone   Dragon
# 210        Ebony Warhammer      25    30.0  1725  Ebony Ingot    Ebony
# ..                     ...     ...     ...   ...          ...      ...
# 34             Iron Dagger       4     2.0    10   Iron Ingot      NaN
# 42                    Shiv       5     2.0     5          NaN        -
# 22     Alessandra's Dagger       5     1.0    10          NaN        -
# 101             Ghostblade       8     1.0   300  3 Ectoplasm      NaN
# 126          Phantom Sword       1     0.0     0          NaN        -
#
#           Type    Category  Speed
# 20   Battleaxe  Two-Handed    NaN
# 208  Warhammer  Two-Handed    NaN
# 205  Warhammer  Two-Handed    NaN
# 2    Battleaxe  Two-Handed    NaN
# 210  Warhammer  Two-Handed    NaN
# ..         ...         ...    ...
# 34      Dagger  One-Handed    NaN
# 42      Dagger  One-Handed    NaN
# 22      Dagger  One-Handed    NaN
# 101      Sword  One-Handed    NaN
# 126      Sword  One-Handed    NaN
#
# [263 rows x 9 columns]

# %% [markdown]
# We can the heaview weapons have a mean damage above 30 and are mostly 2 handed

# %%
sns.regplot(x=SkyrimWeaponsData['Weight'], y=SkyrimWeaponsData['Damage'])
# Out:
# <Axes: xlabel='Weight', ylabel='Damage'>

# %%
plt.rcParams['figure.figsize'] = 22,10
sns.barplot(y=SkyrimWeaponsData['Weight'], x=SkyrimWeaponsData['Damage'], hue=SkyrimWeaponsData['Category'])
# Out:
# <Axes: xlabel='Damage', ylabel='Weight'>

# %% [markdown]
# We can see a clear relation between weight, type and damage. two handed weapons have more weight and more damage than bows and one handed weapons

# %%
plt.rcParams['figure.figsize'] = 32,18
sns.countplot(x='Upgrade', data=SkyrimWeaponsData)
# Out:
# <Axes: xlabel='Upgrade', ylabel='count'>

# %% [markdown]
# most of the weapons can be upgraded with steel, ebony and iron ingots

# %%
sns.regplot(x=SkyrimWeaponsData['Damage'], y=SkyrimWeaponsData['Gold'])
# Out:
# <Axes: xlabel='Damage', ylabel='Gold'>

# %%
sns.barplot(x=SkyrimWeaponsData['Type'], y=SkyrimWeaponsData['Gold'], hue=SkyrimWeaponsData['Category'])
# Out:
# <Axes: xlabel='Type', ylabel='Gold'>

# %% [markdown]
# We can see that weapons that do more dmaage have more weight and sell for more gold

# %%
# H0: weight and damage are related

tmp = SkyrimWeaponsData.iloc[:,1:3]
tmp = tmp.loc[tmp['Damage'] != 0]
tmp = tmp.loc[tmp['Weight'] != 0]
tmp

x, p_Value, y,z = scipy.stats.chi2_contingency(tmp)
print('P_Value: ', p_Value)
# Out:
# P_Value:  0.9999869679872709

# %% [markdown]
# P_value of 0.99 is > 0.05 so null hypothesis is true and we can conclude that gold and damage are related

# %%
SkyrimWeaponsData = pd.read_csv(filePath)
SkyrimAmmoData = SkyrimWeaponsData.loc[(SkyrimWeaponsData['Type'] == 'Arrow') | (SkyrimWeaponsData['Type'] == 'Bolt')]
SkyrimAmmoData
# Out:
#                                 Name  Damage  Weight  Gold Upgrade Perk
# 261               Ancient Nord Arrow      10     0.0     1     NaN  NaN  \
# 262       Bloodcursed Elven Arrow DG      16     0.0     6     NaN  NaN
# 263                    Daedric Arrow      24     0.0     8     NaN  NaN
# 264              Dragonbone Arrow DG      25     0.0     9     NaN  NaN
# 265                    Dwarven Arrow      14     0.0     4     NaN  NaN
# 266   Dwarven Sphere Centurion Arrow      20     0.0     0     NaN  NaN
# 267                      Ebony Arrow      20     0.0     7     NaN  NaN
# 268                      Elven Arrow      16     0.0     5     NaN  NaN
# 269                     Falmer Arrow       7     0.0     1     NaN  NaN
# 270                   Forsworn Arrow       7     0.0     1     NaN  NaN
# 271                      Glass Arrow      18     0.0     6     NaN  NaN
# 272                       Iron Arrow       8     0.0     1     NaN  NaN
# 273                  Nordic Arrow DR      14     0.0     4     NaN  NaN
# 274                     Orcish Arrow      12     0.0     3     NaN  NaN
# 275                   Practice Arrow       0     0.0     0     NaN  NaN
# 276                Riekling Spear DR      10     0.0     2     NaN  NaN
# 277                      Rusty Arrow       4     0.0     0     NaN  NaN
# 278                Stalhrim Arrow DR      20     0.0     7     NaN  NaN
# 279                      Steel Arrow      10     0.0     2     NaN  NaN
# 280       Sunhallowed Elven Arrow DG      16     0.0    16     NaN  NaN
# 285                       Steel Bolt      10     0.0     1     NaN  NaN
# 286                     Dwarven Bolt      14     0.0     3     NaN  NaN
# 287     Exploding Steel Bolt of Fire      10     0.0     5     NaN  NaN
# 288      Exploding Steel Bolt of Ice      10     0.0     5     NaN  NaN
# 289    Exploding Steel Bolt of Shock      10     0.0     5     NaN  NaN
# 290   Exploding Dwarven Bolt of Fire      14     0.0    15     NaN  NaN
# 291    Exploding Dwarven Bolt of Ice      14     0.0    15     NaN  NaN
# 292  Exploding Dwarven Bolt of Shock      14     0.0    15     NaN  NaN
#
#       Type Category  Speed
# 261  Arrow  Archery    NaN
# 262  Arrow  Archery    NaN
# 263  Arrow  Archery    NaN
# 264  Arrow  Archery    NaN
# 265  Arrow  Archery    NaN
# 266  Arrow  Archery    NaN
# 267  Arrow  Archery    NaN
# 268  Arrow  Archery    NaN
# 269  Arrow  Archery    NaN
# 270  Arrow  Archery    NaN
# 271  Arrow  Archery    NaN
# 272  Arrow  Archery    NaN
# 273  Arrow  Archery    NaN
# 274  Arrow  Archery    NaN
# 275  Arrow  Archery    NaN
# 276  Arrow  Archery    NaN
# 277  Arrow  Archery    NaN
# 278  Arrow  Archery    NaN
# 279  Arrow  Archery    NaN
# 280  Arrow  Archery    NaN
# 285   Bolt  Archery    NaN
# 286   Bolt  Archery    NaN
# 287   Bolt  Archery    NaN
# 288   Bolt  Archery    NaN
# 289   Bolt  Archery    NaN
# 290   Bolt  Archery    NaN
# 291   Bolt  Archery    NaN
# 292   Bolt  Archery    NaN

# %%
SkyrimAmmoData.sort_values('Damage', ascending=False).head()
# Out:
#                                Name  Damage  Weight  Gold Upgrade Perk   Type
# 264             Dragonbone Arrow DG      25     0.0     9     NaN  NaN  Arrow  \
# 263                   Daedric Arrow      24     0.0     8     NaN  NaN  Arrow
# 278               Stalhrim Arrow DR      20     0.0     7     NaN  NaN  Arrow
# 266  Dwarven Sphere Centurion Arrow      20     0.0     0     NaN  NaN  Arrow
# 267                     Ebony Arrow      20     0.0     7     NaN  NaN  Arrow
#
#     Category  Speed
# 264  Archery    NaN
# 263  Archery    NaN
# 278  Archery    NaN
# 266  Archery    NaN
# 267  Archery    NaN

# %% [markdown]
# We can see arrows are clearly superior to bolts in terms of damage

# %%
SkyrimAmmoData.sort_values('Damage', ascending=True).head()
# Out:
#                Name  Damage  Weight  Gold Upgrade Perk   Type Category  Speed
# 275  Practice Arrow       0     0.0     0     NaN  NaN  Arrow  Archery    NaN
# 277     Rusty Arrow       4     0.0     0     NaN  NaN  Arrow  Archery    NaN
# 269    Falmer Arrow       7     0.0     1     NaN  NaN  Arrow  Archery    NaN
# 270  Forsworn Arrow       7     0.0     1     NaN  NaN  Arrow  Archery    NaN
# 272      Iron Arrow       8     0.0     1     NaN  NaN  Arrow  Archery    NaN

# %% [markdown]
# The lowest performing category is also arrows

# %%
plt.rcParams['figure.figsize'] = 4,3
sns.boxplot(x=SkyrimAmmoData['Type'], y=SkyrimAmmoData['Damage'])
# Out:
# <Axes: xlabel='Type', ylabel='Damage'>

# %% [markdown]
# Arrows have a higher mean damage but the standard deviation for arrows is also much greater than bolts

# %%
sns.boxplot(x=SkyrimAmmoData['Type'], y=SkyrimAmmoData['Gold'])
# Out:
# <Axes: xlabel='Type', ylabel='Gold'>

# %% [markdown]
# Bolts cost much more than arrows and have a much lower base damage

# %%
SkyrimSilverwareData = SkyrimWeaponsData.loc[SkyrimWeaponsData['Type'] == 'Silverware']
SkyrimSilverwareData
# Out:
#       Name  Damage  Weight  Gold Upgrade Perk        Type    Category  Speed
# 181   Fork       1     0.5     5     NaN  NaN  Silverware  One-Handed    NaN
# 182  Knife       2     0.5     1     NaN  NaN  Silverware  One-Handed    NaN

# %% [markdown]
# Skyrim silverware is classified as one handed, and they also have weight and damage values.

# %% [markdown]
# **Conclusions**:
#
#     One handed weapons have the lowest base damage, followed by bows and Two handed weapons
#     Warhammers had the highest base attack while Daggers had the lowest base attack
#     Bows had an outlier 'Karliah's Bow' which had a base damage of 25 which is 3 lesser than the Dragonbone warhammer
#     Two handed weapons costed more, weighed more and had higher base damage compared to bows and one handed weapons
#     Most of the weapons can be upgraded by Steel ingots and Ebony ingots
#     Weapons dealing more damage had much higher cost compared to weapons dealing lower damage
#     Warhammers cost the most gold while Daggers cost the least
#     The Chi Sq Test for Independence suggests that Weight and Damage are related
#     In ammo types Arrows are the best and worst performing
#     Arrows have a higher mean damage than bolts
#     Bolts cost much more than arrows
#     Silverware is concidered one handed and has terrible damage

# %% [markdown]
# |
