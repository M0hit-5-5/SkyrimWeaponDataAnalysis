# %%
import pandas as pd
import numpy as np

# %%
unCleanData = pd.read_csv('../data/SkyrimWeapons.csv')
unCleanData.head()
# Out:
#                       Name  Damage  Weight  Gold              Upgrade
# 0  Ancient Nord Battle Axe      18    22.0    28          Steel Ingot  \
# 1        Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2    Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 3     Drainblood Battleaxe      21     5.0   266                  NaN
# 4        Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
#
#       Perk       Type    Category  Speed
# 0    Steel  Battleaxe  Two-Handed    NaN
# 1  Daedric  Battleaxe  Two-Handed    NaN
# 2   Dragon  Battleaxe  Two-Handed    NaN
# 3        -  Battleaxe  Two-Handed    NaN
# 4  Dwarven  Battleaxe  Two-Handed    NaN

# %% [markdown]
# Remove speed col as most of it is NaN

# %%
unCleanData = unCleanData.iloc[:,:-1]   # select everything except speed col
unCleanData
# Out:
#                                 Name  Damage  Weight  Gold
# 0            Ancient Nord Battle Axe      18    22.0    28  \
# 1                  Daedric Battleaxe      25    27.0  2750
# 2              Dragonbone Battleaxe       26    30.0  3000
# 3               Drainblood Battleaxe      21     5.0   266
# 4                  Dwarven Battleaxe      20    23.0   300
# ..                               ...     ...     ...   ...
# 288      Exploding Steel Bolt of Ice      10     0.0     5
# 289    Exploding Steel Bolt of Shock      10     0.0     5
# 290   Exploding Dwarven Bolt of Fire      14     0.0    15
# 291    Exploding Dwarven Bolt of Ice      14     0.0    15
# 292  Exploding Dwarven Bolt of Shock      14     0.0    15
#
#                  Upgrade     Perk       Type    Category
# 0            Steel Ingot    Steel  Battleaxe  Two-Handed
# 1            Ebony Ingot  Daedric  Battleaxe  Two-Handed
# 2            Dragon Bone   Dragon  Battleaxe  Two-Handed
# ...

# %% [markdown]
# Remove silverware, arrows and bolts

# %%
unCleanData = unCleanData.loc[(unCleanData['Type'] != 'Bolt') & (unCleanData['Type'] != 'Arrow') & (unCleanData['Type'] != 'Silverware')]

# %%
unCleanData['Upgrade'] = unCleanData['Upgrade'].replace(to_replace=np.NaN, value='No Upgrade')
unCleanData
# Out:
# /tmp/ipykernel_16435/3715427409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unCleanData['Upgrade'] = unCleanData['Upgrade'].replace(to_replace=np.NaN, value='No Upgrade')
#                           Name  Damage  Weight  Gold              Upgrade
# 0      Ancient Nord Battle Axe      18    22.0    28          Steel Ingot  \
# 1            Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2        Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 3         Drainblood Battleaxe      21     5.0   266           No Upgrade
# 4            Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
# ..                         ...     ...     ...   ...                  ...
# ...

# %% [markdown]
# Drop perk because most of the rows arent filled

# %%
unCleanData.pop('Perk')
# Out:
# 0        Steel
# 1      Daedric
# 2       Dragon
# 3            -
# 4      Dwarven
#         ...
# 260    Dwarven
# 281        NaN
# 282        NaN
# 283        NaN
# 284        NaN
# Name: Perk, Length: 263, dtype: object

# %%
cleanedData = unCleanData

# %%
pd.DataFrame.to_csv(cleanedData, '../data/CleanSkyrimData.csv')
